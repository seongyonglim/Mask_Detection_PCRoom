# %%
import os
import platform
from IPython.display import clear_output
from IPython.display import HTML
from base64 import b64encode
from tensorflow.keras.models import load_model
from collections import deque
import matplotlib.pyplot as plt
import numpy as np
import argparse
import pickle
import cv2
import warnings
warnings.filterwarnings("ignore")
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\admin\AppData\Local\Temp/ipykernel_19960/1515776653.py", line 6, in <module>
#     from tensorflow.keras.models import load_model
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow\__init__.py", line 101, in <module>
#     from tensorflow_core import *
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\__init__.py", line 40, in <module>
#     from tensorflow.python.tools import module_util as _module_util
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\Users\admin\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\python\__init__.py", line 75, in <module>
#     from tensorflow.python.framework.framework_lib import *  # pylint: disable=redefined-builtin
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\python\framework\framework_lib.py", line 25, in <module>
#     from tensorflow.python.framework.ops import Graph
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\python\framework\ops.py", line 46, in <module>
#     from tensorflow.python.framework import composite_tensor
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\python\framework\composite_tensor.py", line 27, in <module>
#     from tensorflow.python.util import nest
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\python\util\nest.py", line 40, in <module>
#     import wrapt as _wrapt
# ModuleNotFoundError: No module named 'wrapt'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ModuleNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\admin\anaconda3\lib\inspect.py", line 1495, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\admin\anaconda3\lib\inspect.py", line 1453, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\admin\anaconda3\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\admin\anaconda3\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\Users\admin\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 953, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 967, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 677, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\__init__.py", line 42, in <module>
#     from . _api.v2 import audio
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\_api\v2\audio\__init__.py", line 10, in <module>
#     from tensorflow.python.ops.gen_audio_ops import decode_wav
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\python\ops\gen_audio_ops.py", line 12, in <module>
#     from tensorflow.python.eager import execute as _execute
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\python\eager\execute.py", line 28, in <module>
#     from tensorflow.python.framework import ops
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\python\framework\ops.py", line 46, in <module>
#     from tensorflow.python.framework import composite_tensor
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\python\framework\composite_tensor.py", line 27, in <module>
#     from tensorflow.python.util import nest
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\python\util\nest.py", line 40, in <module>
#     import wrapt as _wrapt
# ModuleNotFoundError: No module named 'wrapt'
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\admin\AppData\Local\Temp/ipykernel_19960/1515776653.py", line 6, in <module>
#     from tensorflow.keras.models import load_model
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow\__init__.py", line 101, in <module>
#     from tensorflow_core import *
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\__init__.py", line 40, in <module>
#     from tensorflow.python.tools import module_util as _module_util
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\Users\admin\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\python\__init__.py", line 75, in <module>
#     from tensorflow.python.framework.framework_lib import *  # pylint: disable=redefined-builtin
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\python\framework\framework_lib.py", line 25, in <module>
#     from tensorflow.python.framework.ops import Graph
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\python\framework\ops.py", line 46, in <module>
#     from tensorflow.python.framework import composite_tensor
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\python\framework\composite_tensor.py", line 27, in <module>
#     from tensorflow.python.util import nest
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\python\util\nest.py", line 40, in <module>
#     import wrapt as _wrapt
# ModuleNotFoundError: No module named 'wrapt'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ModuleNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3364, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3461, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2067, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\admin\anaconda3\lib\inspect.py", line 1495, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\admin\anaconda3\lib\inspect.py", line 1453, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\admin\anaconda3\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\admin\anaconda3\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\Users\admin\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 953, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 967, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 677, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\__init__.py", line 42, in <module>
#     from . _api.v2 import audio
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\_api\v2\audio\__init__.py", line 10, in <module>
#     from tensorflow.python.ops.gen_audio_ops import decode_wav
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\python\ops\gen_audio_ops.py", line 12, in <module>
#     from tensorflow.python.eager import execute as _execute
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\python\eager\execute.py", line 28, in <module>
#     from tensorflow.python.framework import ops
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\python\framework\ops.py", line 46, in <module>
#     from tensorflow.python.framework import composite_tensor
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\python\framework\composite_tensor.py", line 27, in <module>
#     from tensorflow.python.util import nest
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\python\util\nest.py", line 40, in <module>
#     import wrapt as _wrapt
# ModuleNotFoundError: No module named 'wrapt'
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\admin\AppData\Local\Temp/ipykernel_19960/1515776653.py", line 6, in <module>
#     from tensorflow.keras.models import load_model
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow\__init__.py", line 101, in <module>
#     from tensorflow_core import *
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\__init__.py", line 40, in <module>
#     from tensorflow.python.tools import module_util as _module_util
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\Users\admin\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\python\__init__.py", line 75, in <module>
#     from tensorflow.python.framework.framework_lib import *  # pylint: disable=redefined-builtin
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\python\framework\framework_lib.py", line 25, in <module>
#     from tensorflow.python.framework.ops import Graph
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\python\framework\ops.py", line 46, in <module>
#     from tensorflow.python.framework import composite_tensor
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\python\framework\composite_tensor.py", line 27, in <module>
#     from tensorflow.python.util import nest
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\python\util\nest.py", line 40, in <module>
#     import wrapt as _wrapt
# ModuleNotFoundError: No module named 'wrapt'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ModuleNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3364, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3461, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2067, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2947, in _run_cell
#     return runner(coro)
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3173, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3383, in run_ast_nodes
#     self.showtraceback()
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2067, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1143, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\admin\anaconda3\lib\inspect.py", line 1495, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\admin\anaconda3\lib\inspect.py", line 1453, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\admin\anaconda3\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\admin\anaconda3\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\Users\admin\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 953, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 967, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 677, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\__init__.py", line 42, in <module>
#     from . _api.v2 import audio
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\_api\v2\audio\__init__.py", line 10, in <module>
#     from tensorflow.python.ops.gen_audio_ops import decode_wav
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\python\ops\gen_audio_ops.py", line 12, in <module>
#     from tensorflow.python.eager import execute as _execute
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\python\eager\execute.py", line 28, in <module>
#     from tensorflow.python.framework import ops
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\python\framework\ops.py", line 46, in <module>
#     from tensorflow.python.framework import composite_tensor
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\python\framework\composite_tensor.py", line 27, in <module>
#     from tensorflow.python.util import nest
#   File "C:\Users\admin\anaconda3\lib\site-packages\tensorflow_core\python\util\nest.py", line 40, in <module>
#     import wrapt as _wrapt
# ModuleNotFoundError: No module named 'wrapt'

# %% [markdown]
# ## **Testing**

# %%
xml = 'haarcascades/haarcascade_frontalface_default.xml'
face_cascade = cv2.CascadeClassifier(xml)

cap = cv2.VideoCapture(0) # 노트북 웹캠을 카메라로 사용
cap.set(3,640) # 너비
cap.set(4,480) # 높이

flag =0
model = load_model('DenseNet121.h5')
while(True):
    ret, frame = cap.read()
    frame = cv2.flip(frame, 1) # 좌우 대칭
    img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    output = cv2.resize(img, (512, 360)).copy()
    processed_img = cv2.resize(img,(128,128))
    processed_img = np.reshape(processed_img,[1,128,128,3])
    processed_img = processed_img/255.0

    prediction = model.predict(processed_img)[0][0] # 사진의 결과값 에측


    # 해당 프레임마다 모델의 예측 결과를 텍스트로 채워주기
    text_color = (0, 255, 0) # default : green

    if prediction > 0.50 : # mask prob
        text_color = (0, 0, 255) # red
        label = 'wearing a mask'
        flag = 0
    else:
        label = 'Not wearing a mask'
        flag = flag+1
    if flag >= 10:
        text = "State : warning "
    else:
        text = "State : {:8} ({:3.2f}%)".format(label,prediction*100)
    FONT = cv2.FONT_HERSHEY_SIMPLEX 

    cv2.putText(output, text, (35, 50), FONT,1.25, text_color, 3) 
    output = cv2.rectangle(output, (35, 80), (35+int(preds[0])*5,80+20), text_color,-1)

    if writer is None:
        fourcc = cv2.VideoWriter_fourcc(*"MJPG")
        writer = cv2.VideoWriter(args["output"], fourcc, 30,(W, H), True)
    writer.write(output)

    # 프레임 이미지를 출력하기
    cv2_imshow(output)
    key = cv2.waitKey(1) & 0xFF
    if key == ord("q"):
        break
# Out:
# Output hidden; open in https://colab.research.google.com to view.
